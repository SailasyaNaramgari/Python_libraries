# %%
#INTRODUCTION

# %%
import pandas as pd

# %%
df = pd.read_csv('data/survey_results_public.csv')

# %%
df
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 1               2             I am a student who is learning to code       No
# 2               3  I am not primarily a developer, but I write co...      Yes
# 3               4                     I am a developer by profession       No
# 4               5                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 88878       88377                                                NaN      Yes
# 88879       88601                                                NaN       No
# 88880       88802                                                NaN       No
# 88881       88816                                                NaN       No
# 88882       88863                                                NaN      Yes
#
# ...

# %%
df.head()
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1             I am a student who is learning to code      Yes
# 1           2             I am a student who is learning to code       No
# 2           3  I am not primarily a developer, but I write co...      Yes
# 3           4                     I am a developer by profession       No
# 4           5                     I am a developer by profession      Yes
#
#                   OpenSourcer  \
# 0                       Never
# 1     Less than once per year
# 2                       Never
# 3                       Never
# 4  Once a month or more often
#
#                                           OpenSource  \
# 0  The quality of OSS and closed source software ...
# 1  The quality of OSS and closed source software ...
# 2  The quality of OSS and closed source software ...
# 3  The quality of OSS and closed source software ...
# 4  OSS is, on average, of HIGHER quality than pro...
#
# ...

# %%
df.head(7)
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1             I am a student who is learning to code      Yes
# 1           2             I am a student who is learning to code       No
# 2           3  I am not primarily a developer, but I write co...      Yes
# 3           4                     I am a developer by profession       No
# 4           5                     I am a developer by profession      Yes
# 5           6  I am not primarily a developer, but I write co...      Yes
# 6           7                     I am a developer by profession       No
#
#                   OpenSourcer  \
# 0                       Never
# 1     Less than once per year
# 2                       Never
# 3                       Never
# 4  Once a month or more often
# 5                       Never
# 6                       Never
#
#                                           OpenSource  \
# 0  The quality of OSS and closed source software ...
# ...

# %%
df.tail(7)
# Out:
#        Respondent MainBranch Hobbyist  \
# 88876       88212        NaN       No
# 88877       88282        NaN      Yes
# 88878       88377        NaN      Yes
# 88879       88601        NaN       No
# 88880       88802        NaN       No
# 88881       88816        NaN       No
# 88882       88863        NaN      Yes
#
#                                              OpenSourcer  \
# 88876                            Less than once per year
# 88877                         Once a month or more often
# 88878  Less than once a month but more than once per ...
# 88879                                              Never
# 88880                                              Never
# 88881                                              Never
# 88882                            Less than once per year
#
#                                               OpenSource  \
# 88876  OSS is, on average, of HIGHER quality than pro...
# 88877  The quality of OSS and closed source software ...
# ...

# %%
#shape gives us rows and columns

df.shape
# Out:
# (88883, 85)

# %%
df.info()  #object means string
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88883 entries, 0 to 88882
# Data columns (total 85 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Respondent              88883 non-null  int64
#  1   MainBranch              88331 non-null  object
#  2   Hobbyist                88883 non-null  object
#  3   OpenSourcer             88883 non-null  object
#  4   OpenSource              86842 non-null  object
#  5   Employment              87181 non-null  object
#  6   Country                 88751 non-null  object
#  7   Student                 87014 non-null  object
#  8   EdLevel                 86390 non-null  object
#  9   UndergradMajor          75614 non-null  object
#  10  EduOther                84260 non-null  object
#  11  OrgSize                 71791 non-null  object
#  12  DevType                 81335 non-null  object
#  13  YearsCode               87938 non-null  object
# ...

# %%
pd.set_option('display.max_columns',85)  #show all the columns
pd.set_option('display.max_rows',85)  #show all the rows

# %%
schema_df = pd.read_csv('data/survey_results_schema.csv')

# %%
schema_df
# Out:
#                     Column                                       QuestionText
# 0               Respondent  Randomized respondent ID number (not in order ...
# 1               MainBranch  Which of the following options best describes ...
# 2                 Hobbyist                            Do you code as a hobby?
# 3              OpenSourcer        How often do you contribute to open source?
# 4               OpenSource  How do you feel about the quality of open sour...
# 5               Employment  Which of the following best describes your cur...
# 6                  Country          In which country do you currently reside?
# 7                  Student  Are you currently enrolled in a formal, degree...
# 8                  EdLevel  Which of the following best describes the high...
# 9           UndergradMajor  What was your main or most important field of ...
# 10                EduOther  Which of the following types of non-degree edu...
# ...

# %%
#DATAFRAMES - 2d rows and columns

# %%
#----- Example basics------

# %%
people = {
    "first" : ["Sai"],
    "last" : ["lasya"],
    "email" : ["lasya@gmail.com"]
}

# %%
people = {
    "first" : ["lasya", "janu", "prasu","aishu","sai"],
    "last" : ["naramgari", "guntimadugu","nandigam","buddharaju","naramgari"],
    "email" : ["lasya@gmail.com","janu@gmail.com","prasu@gmail.com","aishu@gmail.com","sai@gmail.com"]
}

# %%
people['email']
# Out:
# ['lasya@gmail.com',
#  'janu@gmail.com',
#  'prasu@gmail.com',
#  'aishu@gmail.com',
#  'sai@gmail.com']

# %%
df1 = pd.DataFrame(people)

# %%
df1
# Out:
#    first         last            email
# 0  lasya    naramgari  lasya@gmail.com
# 1   janu  guntimadugu   janu@gmail.com
# 2  prasu     nandigam  prasu@gmail.com
# 3  aishu   buddharaju  aishu@gmail.com
# 4    sai    naramgari    sai@gmail.com

# %%
df1['email']
# Out:
# 0    lasya@gmail.com
# 1     janu@gmail.com
# 2    prasu@gmail.com
# 3    aishu@gmail.com
# 4      sai@gmail.com
# Name: email, dtype: object

# %%
type(df1['email']) 
#Series is a list of data with df - 1d array - rowm and columns in other terms
#df contains multiple series in it
# Out:
# pandas.core.series.Series

# %%
df1.email
# Out:
# 0    lasya@gmail.com
# 1     janu@gmail.com
# 2    prasu@gmail.com
# 3    aishu@gmail.com
# 4      sai@gmail.com
# Name: email, dtype: object

# %%
#use bracket than dot notation to access to avoid errors

# %%
df1[['last','email']]
# Out:
#           last            email
# 0    naramgari  lasya@gmail.com
# 1  guntimadugu   janu@gmail.com
# 2     nandigam  prasu@gmail.com
# 3   buddharaju  aishu@gmail.com
# 4    naramgari    sai@gmail.com

# %%
type(df1[['last','email']])
# Out:
# pandas.core.frame.DataFrame

# %%
df1.columns
# Out:
# Index(['first', 'last', 'email'], dtype='object')

# %%
#iloc for accessing integer location - accessing rows (integer indexing)

df1.iloc[0]
# Out:
# first              lasya
# last           naramgari
# email    lasya@gmail.com
# Name: 0, dtype: object

# %%
df1.iloc[[0,1,2]]
# Out:
#    first         last            email
# 0  lasya    naramgari  lasya@gmail.com
# 1   janu  guntimadugu   janu@gmail.com
# 2  prasu     nandigam  prasu@gmail.com

# %%
  df1.iloc[[0,1],[2]]  #rows , columns
# Out:
#              email
# 0  lasya@gmail.com
# 1   janu@gmail.com

# %%
df1
# Out:
#    first         last            email
# 0  lasya    naramgari  lasya@gmail.com
# 1   janu  guntimadugu   janu@gmail.com
# 2  prasu     nandigam  prasu@gmail.com
# 3  aishu   buddharaju  aishu@gmail.com
# 4    sai    naramgari    sai@gmail.com

# %%
#loc - label indexing
df1.loc[0]
# Out:
# first              lasya
# last           naramgari
# email    lasya@gmail.com
# Name: 0, dtype: object

# %%
df1.loc[[0,1]]
# Out:
#    first         last            email
# 0  lasya    naramgari  lasya@gmail.com
# 1   janu  guntimadugu   janu@gmail.com

# %%
df1.loc[[0,1],'email']
# Out:
# 0    lasya@gmail.com
# 1     janu@gmail.com
# Name: email, dtype: object

# %%
df1.loc[[0,1],['email','last']]
# Out:
#              email         last
# 0  lasya@gmail.com    naramgari
# 1   janu@gmail.com  guntimadugu

# %%
#--Main----

# %%
df.shape
# Out:
# (88883, 85)

# %%
df.columns
# Out:
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource',
#        'Employment', 'Country', 'Student', 'EdLevel', 'UndergradMajor',
#        'EduOther', 'OrgSize', 'DevType', 'YearsCode', 'Age1stCode',
#        'YearsCodePro', 'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney',
#        'MgrWant', 'JobSeek', 'LastHireDate', 'LastInt', 'FizzBuzz',
#        'JobFactors', 'ResumeUpdate', 'CurrencySymbol', 'CurrencyDesc',
#        'CompTotal', 'CompFreq', 'ConvertedComp', 'WorkWeekHrs', 'WorkPlan',
#        'WorkChallenge', 'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev',
#        'CodeRevHrs', 'UnitTests', 'PurchaseHow', 'PurchaseWhat',
#        'LanguageWorkedWith', 'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
# ...

# %%
df['Hobbyist']
# Out:
# 0        Yes
# 1         No
# 2        Yes
# 3         No
# 4        Yes
#         ...
# 88878    Yes
# 88879     No
# 88880     No
# 88881     No
# 88882    Yes
# Name: Hobbyist, Length: 88883, dtype: object

# %%
#to get the count of unique values
df['Hobbyist'].value_counts()
# Out:
# Hobbyist
# Yes    71257
# No     17626
# Name: count, dtype: int64

# %%
#specific row and column - 1 person result 1st row
df.loc[0]
# Out:
# Respondent                                                                1
# MainBranch                           I am a student who is learning to code
# Hobbyist                                                                Yes
# OpenSourcer                                                           Never
# OpenSource                The quality of OSS and closed source software ...
# Employment                           Not employed, and not looking for work
# Country                                                      United Kingdom
# Student                                                                  No
# EdLevel                                           Primary/elementary school
# UndergradMajor                                                          NaN
# EduOther                  Taught yourself a new language, framework, or ...
# OrgSize                                                                 NaN
# ...

# %%
df.loc[0,'Hobbyist']
# Out:
# 'Yes'

# %%
df.loc[[0,1,2,3],'Hobbyist']
# Out:
# 0    Yes
# 1     No
# 2    Yes
# 3     No
# Name: Hobbyist, dtype: object

# %%
#slicing
df.loc[0:3,'Hobbyist']
# Out:
# 0    Yes
# 1     No
# 2    Yes
# 3     No
# Name: Hobbyist, dtype: object

# %%
df.loc[0:2,['Hobbyist','Employment']]
# Out:
#   Hobbyist                              Employment
# 0      Yes  Not employed, and not looking for work
# 1       No      Not employed, but looking for work
# 2      Yes                      Employed full-time

# %%
df.loc[0:2,'Hobbyist':'Employment']
# Out:
#   Hobbyist              OpenSourcer  \
# 0      Yes                    Never
# 1       No  Less than once per year
# 2      Yes                    Never
#
#                                           OpenSource  \
# 0  The quality of OSS and closed source software ...
# 1  The quality of OSS and closed source software ...
# 2  The quality of OSS and closed source software ...
#
#                                Employment
# 0  Not employed, and not looking for work
# 1      Not employed, but looking for work
# 2                      Employed full-time

# %%
#INDEXING

# %%
#----- Example basics------

# %%
df1
# Out:
#    first         last            email
# 0  lasya    naramgari  lasya@gmail.com
# 1   janu  guntimadugu   janu@gmail.com
# 2  prasu     nandigam  prasu@gmail.com
# 3  aishu   buddharaju  aishu@gmail.com
# 4    sai    naramgari    sai@gmail.com

# %%
df1['email']
# Out:
# 0    lasya@gmail.com
# 1     janu@gmail.com
# 2    prasu@gmail.com
# 3    aishu@gmail.com
# 4      sai@gmail.com
# Name: email, dtype: object

# %%
df1.set_index('email')  #email is set as the index
# Out:
#                  first         last
# email
# lasya@gmail.com  lasya    naramgari
# janu@gmail.com    janu  guntimadugu
# prasu@gmail.com  prasu     nandigam
# aishu@gmail.com  aishu   buddharaju
# sai@gmail.com      sai    naramgari

# %%
df1   #pandas only changes at specific places we are told to
# Out:
#    first         last            email
# 0  lasya    naramgari  lasya@gmail.com
# 1   janu  guntimadugu   janu@gmail.com
# 2  prasu     nandigam  prasu@gmail.com
# 3  aishu   buddharaju  aishu@gmail.com
# 4    sai    naramgari    sai@gmail.com

# %%
df1.set_index('email',inplace= True)     #with inplace , we can change it at all places

# %%
df1
# Out:
#                  first         last
# email
# lasya@gmail.com  lasya    naramgari
# janu@gmail.com    janu  guntimadugu
# prasu@gmail.com  prasu     nandigam
# aishu@gmail.com  aishu   buddharaju
# sai@gmail.com      sai    naramgari

# %%
df1.index
# Out:
# Index(['lasya@gmail.com', 'janu@gmail.com', 'prasu@gmail.com',
#        'aishu@gmail.com', 'sai@gmail.com'],
#       dtype='object', name='email')

# %%
df1.loc['lasya@gmail.com']  #as we used email as index we can access through it
# Out:
# first        lasya
# last     naramgari
# Name: lasya@gmail.com, dtype: object

# %%
df1.loc['lasya@gmail.com','last']
# Out:
# 'naramgari'

# %%
df1.loc[0]  #it shows erros as we changed the index to email
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\indexes\base.py:3790, in Index.get_loc(self, key)
#    3789 try:
# -> 3790     return self._engine.get_loc(casted_key)
#    3791 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
df1.iloc[0]   #index works for iloc though
# Out:
# first        lasya
# last     naramgari
# Name: lasya@gmail.com, dtype: object

# %%
#to reset the index

df1.reset_index(inplace=True)

# %%
df1
# Out:
#              email  first         last
# 0  lasya@gmail.com  lasya    naramgari
# 1   janu@gmail.com   janu  guntimadugu
# 2  prasu@gmail.com  prasu     nandigam
# 3  aishu@gmail.com  aishu   buddharaju
# 4    sai@gmail.com    sai    naramgari

# %%
#--Main--

# %%
df.head()
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1             I am a student who is learning to code      Yes
# 1           2             I am a student who is learning to code       No
# 2           3  I am not primarily a developer, but I write co...      Yes
# 3           4                     I am a developer by profession       No
# 4           5                     I am a developer by profession      Yes
#
#                   OpenSourcer  \
# 0                       Never
# 1     Less than once per year
# 2                       Never
# 3                       Never
# 4  Once a month or more often
#
#                                           OpenSource  \
# 0  The quality of OSS and closed source software ...
# 1  The quality of OSS and closed source software ...
# 2  The quality of OSS and closed source software ...
# 3  The quality of OSS and closed source software ...
# 4  OSS is, on average, of HIGHER quality than pro...
#
# ...

# %%
df.set_index('Respondent').head()  #or we can use --> df = pd.read_csv('data/survey_results_public.csv',index_col='Respondent')
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
#
#                            OpenSourcer  \
# Respondent
# 1                                Never
# 2              Less than once per year
# 3                                Never
# 4                                Never
# 5           Once a month or more often
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
# 3           The quality of OSS and closed source software ...
# ...

# %%
df = pd.read_csv('data/survey_results_public.csv',index_col='Respondent')  #another method

# %%
df.head()
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
#
#                            OpenSourcer  \
# Respondent
# 1                                Never
# 2              Less than once per year
# 3                                Never
# 4                                Never
# 5           Once a month or more often
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
# 3           The quality of OSS and closed source software ...
# ...

# %%
schema_df
# Out:
#                     Column                                       QuestionText
# 0               Respondent  Randomized respondent ID number (not in order ...
# 1               MainBranch  Which of the following options best describes ...
# 2                 Hobbyist                            Do you code as a hobby?
# 3              OpenSourcer        How often do you contribute to open source?
# 4               OpenSource  How do you feel about the quality of open sour...
# 5               Employment  Which of the following best describes your cur...
# 6                  Country          In which country do you currently reside?
# 7                  Student  Are you currently enrolled in a formal, degree...
# 8                  EdLevel  Which of the following best describes the high...
# 9           UndergradMajor  What was your main or most important field of ...
# 10                EduOther  Which of the following types of non-degree edu...
# ...

# %%
schema_df = pd.read_csv('data/survey_results_schema.csv',index_col='Column')

# %%
schema_df
# Out:
#                                                              QuestionText
# Column
# Respondent              Randomized respondent ID number (not in order ...
# MainBranch              Which of the following options best describes ...
# Hobbyist                                          Do you code as a hobby?
# OpenSourcer                   How often do you contribute to open source?
# OpenSource              How do you feel about the quality of open sour...
# Employment              Which of the following best describes your cur...
# Country                         In which country do you currently reside?
# Student                 Are you currently enrolled in a formal, degree...
# EdLevel                 Which of the following best describes the high...
# UndergradMajor          What was your main or most important field of ...
# EduOther                Which of the following types of non-degree edu...
# OrgSize                 Approximately how many people are employed by ...
# ...

# %%
schema_df.loc['MgrIdiot']  #change column to index and use loc to get info about it
# Out:
# QuestionText    How confident are you that your manager knows ...
# Name: MgrIdiot, dtype: object

# %%
schema_df.loc['MgrIdiot','QuestionText']
# Out:
# 'How confident are you that your manager knows what they’re doing?'

# %%
schema_df.sort_index()  #sort in ascending
# Out:
#                                                              QuestionText
# Column
# Age                     What is your age (in years)? If you prefer not...
# Age1stCode              At what age did you write your first line of c...
# BetterLife              Do you think people born today will have a bet...
# BlockchainIs            Blockchain / cryptocurrency technology is prim...
# BlockchainOrg           How is your organization thinking about or imp...
# CareerSat               Overall, how satisfied are you with your caree...
# CodeRev                          Do you review code as part of your work?
# CodeRevHrs              On average, how many hours per week do you spe...
# CompFreq                 Is that compensation weekly, monthly, or yearly?
# CompTotal               What is your current total compensation (salar...
# Containers              How do you use containers (Docker, Open Contai...
# ConvertedComp           Salary converted to annual USD salaries using ...
# ...

# %%
schema_df.sort_index(ascending=False)  #sort in descending
# Out:
#                                                              QuestionText
# Column
# YearsCodePro            How many years have you coded professionally (...
# YearsCode               Including any education, how many years have y...
# WorkWeekHrs              On average, how many hours per week do you work?
# WorkRemote                                How often do you work remotely?
# WorkPlan                          How structured or planned is your work?
# WorkLoc                                   Where would you prefer to work?
# WorkChallenge           Of these options, what are your greatest chall...
# WelcomeChange           Compared to last year, how welcome do you feel...
# WebFrameWorkedWith      Which of the following web frameworks have you...
# WebFrameDesireNextYear  Which of the following web frameworks have you...
# UnitTests               Does your company regularly employ unit tests ...
# UndergradMajor          What was your main or most important field of ...
# ...

# %%
#FILTERING

# %%
#--Example basics---

# %%
df1
# Out:
#              email  first         last
# 0  lasya@gmail.com  lasya    naramgari
# 1   janu@gmail.com   janu  guntimadugu
# 2  prasu@gmail.com  prasu     nandigam
# 3  aishu@gmail.com  aishu   buddharaju
# 4    sai@gmail.com    sai    naramgari

# %%
filt = df1['last']=='naramgari'  #filter is python builtin keyword, so dont use it

# %%
filt
# Out:
# 0     True
# 1    False
# 2    False
# 3    False
# 4     True
# Name: last, dtype: bool

# %%
df1[filt]
# Out:
#              email  first       last
# 0  lasya@gmail.com  lasya  naramgari
# 4    sai@gmail.com    sai  naramgari

# %%
df1.loc[filt]  #in loc we can also use other labels , so it id preferred than the above one
# Out:
#              email  first       last
# 0  lasya@gmail.com  lasya  naramgari
# 4    sai@gmail.com    sai  naramgari

# %%
df1.loc[filt , 'email']
# Out:
# 0    lasya@gmail.com
# 4      sai@gmail.com
# Name: email, dtype: object

# %%
#& for and ; | for or

filt = (df1['last']=='naramgari') & ( df1['first']=='lasya')

# %%
df1.loc[filt]
# Out:
#              email  first       last
# 0  lasya@gmail.com  lasya  naramgari

# %%
filt = (df1['last']=='naramgari') | ( df1['first']=='janu')

# %%
df1.loc[filt]
# Out:
#              email  first         last
# 0  lasya@gmail.com  lasya    naramgari
# 1   janu@gmail.com   janu  guntimadugu
# 4    sai@gmail.com    sai    naramgari

# %%
df1.loc[~filt]  #gives opposite of the above filter
# Out:
#              email  first        last
# 2  prasu@gmail.com  prasu    nandigam
# 3  aishu@gmail.com  aishu  buddharaju

# %%
#--Main--

# %%
df.head()
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
#
#                            OpenSourcer  \
# Respondent
# 1                                Never
# 2              Less than once per year
# 3                                Never
# 4                                Never
# 5           Once a month or more often
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
# 3           The quality of OSS and closed source software ...
# ...

# %%
schema_df.loc['ConvertedComp']
# Out:
# QuestionText    Salary converted to annual USD salaries using ...
# Name: ConvertedComp, dtype: object

# %%
high_salary = (df['ConvertedComp']>70000)

# %%
df.loc[high_salary]
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 6           I am not primarily a developer, but I write co...      Yes
# 9                              I am a developer by profession      Yes
# 13                             I am a developer by profession      Yes
# 16                             I am a developer by profession      Yes
# 22                             I am a developer by profession      Yes
# ...                                                       ...      ...
# 88876                          I am a developer by profession      Yes
# 88877                          I am a developer by profession      Yes
# 88878                          I am a developer by profession      Yes
# 88879                          I am a developer by profession      Yes
# 88882                          I am a developer by profession      Yes
#
#                                                   OpenSourcer  \
# Respondent
# ...

# %%
df.loc[high_salary, ['Country','LanguageWorkedWith','ConvertedComp']]
# Out:
#                    Country                                 LanguageWorkedWith  \
# Respondent
# 6                   Canada                                         Java;R;SQL
# 9              New Zealand  Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;P...
# 13           United States  Bash/Shell/PowerShell;HTML/CSS;JavaScript;PHP;...
# 16          United Kingdom  Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;T...
# 22           United States  Bash/Shell/PowerShell;C++;HTML/CSS;JavaScript;...
# ...                    ...                                                ...
# 88876        United States  Bash/Shell/PowerShell;C#;HTML/CSS;Java;Python;...
# 88877        United States  Bash/Shell/PowerShell;C;Clojure;HTML/CSS;Java;...
# 88878        United States               HTML/CSS;JavaScript;Scala;TypeScript
# 88879              Finland                   Bash/Shell/PowerShell;C++;Python
# 88882          Netherlands             C#;HTML/CSS;Java;JavaScript;PHP;Python
#
# ...

# %%
countries = ['United States' , 'India' , 'United Kingdom' , 'Germany' , 'Canada']
filt = df['Country'].isin(countries)

# %%
df.loc[filt,'Country']
# Out:
# Respondent
# 1        United Kingdom
# 4         United States
# 6                Canada
# 8                 India
# 10                India
#               ...
# 85642     United States
# 85961    United Kingdom
# 86012             India
# 88282     United States
# 88377            Canada
# Name: Country, Length: 45008, dtype: object

# %%
df['LanguageWorkedWith']
# Out:
# Respondent
# 1                          HTML/CSS;Java;JavaScript;Python
# 2                                      C++;HTML/CSS;Python
# 3                                                 HTML/CSS
# 4                                      C;C++;C#;Python;SQL
# 5              C++;HTML/CSS;Java;JavaScript;Python;SQL;VBA
#                                ...
# 88377                        HTML/CSS;JavaScript;Other(s):
# 88601                                                  NaN
# 88802                                                  NaN
# 88816                                                  NaN
# 88863    Bash/Shell/PowerShell;HTML/CSS;Java;JavaScript...
# Name: LanguageWorkedWith, Length: 88883, dtype: object

# %%
filt = df['LanguageWorkedWith'].str.contains('Python',na=False)   #filtering strings

# %%
df.loc[filt,'LanguageWorkedWith']
# Out:
# Respondent
# 1                          HTML/CSS;Java;JavaScript;Python
# 2                                      C++;HTML/CSS;Python
# 4                                      C;C++;C#;Python;SQL
# 5              C++;HTML/CSS;Java;JavaScript;Python;SQL;VBA
# 8        Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
#                                ...
# 84539    Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
# 85738      Bash/Shell/PowerShell;C++;Python;Ruby;Other(s):
# 86566      Bash/Shell/PowerShell;HTML/CSS;Python;Other(s):
# 87739             C;C++;HTML/CSS;JavaScript;PHP;Python;SQL
# 88212                           HTML/CSS;JavaScript;Python
# Name: LanguageWorkedWith, Length: 36443, dtype: object

# %%
filt
# Out:
# Respondent
# 1         True
# 2         True
# 3        False
# 4         True
# 5         True
#          ...
# 88377    False
# 88601    False
# 88802    False
# 88816    False
# 88863    False
# Name: LanguageWorkedWith, Length: 88883, dtype: bool

# %%
df.loc[filt].head()
# Out:
#                                         MainBranch Hobbyist  \
# Respondent
# 1           I am a student who is learning to code      Yes
# 2           I am a student who is learning to code       No
# 4                   I am a developer by profession       No
# 5                   I am a developer by profession      Yes
# 8                      I code primarily as a hobby      Yes
#
#                            OpenSourcer  \
# Respondent
# 1                                Never
# 2              Less than once per year
# 4                                Never
# 5           Once a month or more often
# 8              Less than once per year
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
# 4           The quality of OSS and closed source software ...
# 5           OSS is, on average, of HIGHER quality than pro...
# ...

# %%
#UPDATING VALUES - ALTERING ETC

# %%
#--Example--

# %%
df1
# Out:
#              email  first         last
# 0  lasya@gmail.com  lasya    naramgari
# 1   janu@gmail.com   janu  guntimadugu
# 2  prasu@gmail.com  prasu     nandigam
# 3  aishu@gmail.com  aishu   buddharaju
# 4    sai@gmail.com    sai    naramgari

# %%
df1.columns
# Out:
# Index(['email', 'first', 'last'], dtype='object')

# %%
df1.columns = ['email','first name','last name']   #if you need to change all column names

# %%
df1
# Out:
#              email first name    last name
# 0  lasya@gmail.com      lasya    naramgari
# 1   janu@gmail.com       janu  guntimadugu
# 2  prasu@gmail.com      prasu     nandigam
# 3  aishu@gmail.com      aishu   buddharaju
# 4    sai@gmail.com        sai    naramgari

# %%
df1.columns = [x.upper() for x in df1.columns]

# %%
df1
# Out:
#              EMAIL FIRST NAME    LAST NAME
# 0  lasya@gmail.com      lasya    naramgari
# 1   janu@gmail.com       janu  guntimadugu
# 2  prasu@gmail.com      prasu     nandigam
# 3  aishu@gmail.com      aishu   buddharaju
# 4    sai@gmail.com        sai    naramgari

# %%
df1.columns = df1.columns.str.replace(' ','_')
df1
# Out:
#              EMAIL FIRST_NAME    LAST_NAME
# 0  lasya@gmail.com      lasya    naramgari
# 1   janu@gmail.com       janu  guntimadugu
# 2  prasu@gmail.com      prasu     nandigam
# 3  aishu@gmail.com      aishu   buddharaju
# 4    sai@gmail.com        sai    naramgari

# %%
df1.columns = [x.lower() for x in df1.columns]
df1
# Out:
#              email first_name    last_name
# 0  lasya@gmail.com      lasya    naramgari
# 1   janu@gmail.com       janu  guntimadugu
# 2  prasu@gmail.com      prasu     nandigam
# 3  aishu@gmail.com      aishu   buddharaju
# 4    sai@gmail.com        sai    naramgari

# %%
#if we want to change specific columns
df1.rename(columns = {'first_name' : 'first' , 'last_name' : 'last'})
# Out:
#              email  first         last
# 0  lasya@gmail.com  lasya    naramgari
# 1   janu@gmail.com   janu  guntimadugu
# 2  prasu@gmail.com  prasu     nandigam
# 3  aishu@gmail.com  aishu   buddharaju
# 4    sai@gmail.com    sai    naramgari

# %%
df1
# Out:
#              email first_name    last_name
# 0  lasya@gmail.com      lasya    naramgari
# 1   janu@gmail.com       janu  guntimadugu
# 2  prasu@gmail.com      prasu     nandigam
# 3  aishu@gmail.com      aishu   buddharaju
# 4    sai@gmail.com        sai    naramgari

# %%
df1.rename(columns = {'first_name' : 'first' , 'last_name' : 'last'} , inplace = True)  #to make it permanent

# %%
df1
# Out:
#              email  first         last
# 0  lasya@gmail.com  lasya    naramgari
# 1   janu@gmail.com   janu  guntimadugu
# 2  prasu@gmail.com  prasu     nandigam
# 3  aishu@gmail.com  aishu   buddharaju
# 4    sai@gmail.com    sai    naramgari

# %%
df1.loc[2]
# Out:
# email    prasu@gmail.com
# first              prasu
# last            nandigam
# Name: 2, dtype: object

# %%
df1.loc[2] = ['prasanna@gmail.com','prasanna' , 'nandigam' ]

# %%
df1
# Out:
#                 email     first         last
# 0     lasya@gmail.com     lasya    naramgari
# 1      janu@gmail.com      janu  guntimadugu
# 2  prasanna@gmail.com  prasanna     nandigam
# 3     aishu@gmail.com     aishu   buddharaju
# 4       sai@gmail.com       sai    naramgari

# %%
df1.loc[2 , ['email','first']]
# Out:
# email    prasanna@gmail.com
# first              prasanna
# Name: 2, dtype: object

# %%
df1.loc[2 , ['email','first']] = ['prasu@gmail.com','prasu']
df1
# Out:
#              email  first         last
# 0  lasya@gmail.com  lasya    naramgari
# 1   janu@gmail.com   janu  guntimadugu
# 2  prasu@gmail.com  prasu     nandigam
# 3  aishu@gmail.com  aishu   buddharaju
# 4    sai@gmail.com    sai    naramgari

# %%
df1.loc[2 ,'first'] = 'prasanna'
df1
# Out:
#              email     first         last
# 0  lasya@gmail.com     lasya    naramgari
# 1   janu@gmail.com      janu  guntimadugu
# 2  prasu@gmail.com  prasanna     nandigam
# 3  aishu@gmail.com     aishu   buddharaju
# 4    sai@gmail.com       sai    naramgari

# %%
df1.at[2 ,'email'] = 'prasanna@gmail.com'    #for changing single column we can use at
df1
# Out:
#                 email     first         last
# 0     lasya@gmail.com     lasya    naramgari
# 1      janu@gmail.com      janu  guntimadugu
# 2  prasanna@gmail.com  prasanna     nandigam
# 3     aishu@gmail.com     aishu   buddharaju
# 4       sai@gmail.com       sai    naramgari

# %%
filt = (df1['email'] == 'lasya@gmail.com')
df1[filt]['last'] = 'Naramgari'   #we cannot change it like that
df1  #doesn't change anything
# Out:
# C:\Users\91628\AppData\Local\Temp\ipykernel_45028\3810967218.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1[filt]['last'] = 'Naramgari'   #we cannot change it like that
#                 email     first         last
# 0     lasya@gmail.com     lasya    naramgari
# 1      janu@gmail.com      janu  guntimadugu
# 2  prasanna@gmail.com  prasanna     nandigam
# 3     aishu@gmail.com     aishu   buddharaju
# 4       sai@gmail.com       sai    naramgari

# %%
filt = (df1['email'] == 'lasya@gmail.com')
df1.loc[filt,'last'] = 'naramgaris'   
df1
# Out:
#                 email     first         last
# 0     lasya@gmail.com     lasya   naramgaris
# 1      janu@gmail.com      janu  guntimadugu
# 2  prasanna@gmail.com  prasanna     nandigam
# 3     aishu@gmail.com     aishu   buddharaju
# 4       sai@gmail.com       sai    naramgari

# %%
df1['email'].str.upper()
# Out:
# 0       LASYA@GMAIL.COM
# 1        JANU@GMAIL.COM
# 2    PRASANNA@GMAIL.COM
# 3       AISHU@GMAIL.COM
# 4         SAI@GMAIL.COM
# Name: email, dtype: object

# %%
df1['email'] = df1['email'].str.lower()
df1
# Out:
#                 email     first         last
# 0     lasya@gmail.com     lasya   naramgaris
# 1      janu@gmail.com      janu  guntimadugu
# 2  prasanna@gmail.com  prasanna     nandigam
# 3     aishu@gmail.com     aishu   buddharaju
# 4       sai@gmail.com       sai    naramgari

# %%
#apply
#map
#applymap
#replace

# %%
#Apply - apply functon on series or dataframes

# %%
#for series

# %%
df1['email'].apply(len)
# Out:
# 0    15
# 1    14
# 2    18
# 3    15
# 4    13
# Name: email, dtype: int64

# %%
def update_email(email):    #1st apply method
    return email.upper()

# %%
df1['email'].apply(update_email)
# Out:
# 0       LASYA@GMAIL.COM
# 1        JANU@GMAIL.COM
# 2    PRASANNA@GMAIL.COM
# 3       AISHU@GMAIL.COM
# 4         SAI@GMAIL.COM
# Name: email, dtype: object

# %%
df1['email']= df1['email'].apply(update_email)
df1
# Out:
#                 email     first         last
# 0     LASYA@GMAIL.COM     lasya   naramgaris
# 1      JANU@GMAIL.COM      janu  guntimadugu
# 2  PRASANNA@GMAIL.COM  prasanna     nandigam
# 3     AISHU@GMAIL.COM     aishu   buddharaju
# 4       SAI@GMAIL.COM       sai    naramgari

# %%
df1['email']= df1['email'].apply(lambda x : x.lower())  #2nd apply method

# %%
df1
# Out:
#                 email     first         last
# 0     lasya@gmail.com     lasya   naramgaris
# 1      janu@gmail.com      janu  guntimadugu
# 2  prasanna@gmail.com  prasanna     nandigam
# 3     aishu@gmail.com     aishu   buddharaju
# 4       sai@gmail.com       sai    naramgari

# %%
#for dataframes

# %%
df1['email'].apply(len)
# Out:
# 0    15
# 1    14
# 2    18
# 3    15
# 4    13
# Name: email, dtype: int64

# %%
df1.apply(len)  #applying it to the column
# Out:
# email    5
# first    5
# last     5
# dtype: int64

# %%
df1.apply(len , axis = 'columns')  #applying it to the row by changing axis
# Out:
# 0    3
# 1    3
# 2    3
# 3    3
# 4    3
# dtype: int64

# %%
len(df1['email'])
# Out:
# 5

# %%
df1.apply(pd.Series.min)  #according to the alphabets
# Out:
# email    aishu@gmail.com
# first              aishu
# last          buddharaju
# dtype: object

# %%
df1.apply(lambda x : x.min())   #lambda for series
# Out:
# email    aishu@gmail.com
# first              aishu
# last          buddharaju
# dtype: object

# %%
#APPLY MAP - only for dataframes not for series

# %%
df1.applymap(len)   #applying function to every individual in the df
# Out:
# C:\Users\91628\AppData\Local\Temp\ipykernel_45028\2640686129.py:1: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df1.applymap(len)   #applying function to every individual in the df
#    email  first  last
# 0     15      5    10
# 1     14      4    11
# 2     18      8     8
# 3     15      5    10
# 4     13      3     9

# %%
df1.applymap(str.lower)
# Out:
# C:\Users\91628\AppData\Local\Temp\ipykernel_45028\3941193034.py:1: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df1.applymap(str.lower)
#                 email     first         last
# 0     lasya@gmail.com     lasya   naramgaris
# 1      janu@gmail.com      janu  guntimadugu
# 2  prasanna@gmail.com  prasanna     nandigam
# 3     aishu@gmail.com     aishu   buddharaju
# 4       sai@gmail.com       sai    naramgari

# %%
#MAP

# %%
df1['first'].map({'lasya' : 'kutti' , 'janu' : 'jahnavi'}) 
 #the names we didn't converted gave nan values if we don't want that you can use replace
# Out:
# 0      kutti
# 1    jahnavi
# 2        NaN
# 3        NaN
# 4        NaN
# Name: first, dtype: object

# %%
#REPLACE

# %%
df1['first'].replace({'lasya' : 'kutti' , 'janu' : 'jahnavi'})
# Out:
# 0       kutti
# 1     jahnavi
# 2    prasanna
# 3       aishu
# 4         sai
# Name: first, dtype: object

# %%
df1['first'] = df1['first'].replace({'lasya' : 'kutti' , 'janu' : 'jahnavi'}) 
df1
# Out:
#                 email     first         last
# 0     lasya@gmail.com     kutti   naramgaris
# 1      janu@gmail.com   jahnavi  guntimadugu
# 2  prasanna@gmail.com  prasanna     nandigam
# 3     aishu@gmail.com     aishu   buddharaju
# 4       sai@gmail.com       sai    naramgari

# %%
#--Main--

# %%
df.head()
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
#
#                            OpenSourcer  \
# Respondent
# 1                                Never
# 2              Less than once per year
# 3                                Never
# 4                                Never
# 5           Once a month or more often
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
# 3           The quality of OSS and closed source software ...
# ...

# %%
df.rename(columns = {'ConvertedComp' : 'SalaryUSD'})
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
# ...                                                       ...      ...
# 88377                                                     NaN      Yes
# 88601                                                     NaN       No
# 88802                                                     NaN       No
# 88816                                                     NaN       No
# 88863                                                     NaN      Yes
#
#                                                   OpenSourcer  \
# Respondent
# ...

# %%
df.rename(columns = {'ConvertedComp' : 'SalaryUSD'} , inplace = True) #make it permanent

# %%
df['SalaryUSD']
# Out:
# Respondent
# 1            NaN
# 2            NaN
# 3         8820.0
# 4        61000.0
# 5            NaN
#           ...
# 88377        NaN
# 88601        NaN
# 88802        NaN
# 88816        NaN
# 88863        NaN
# Name: SalaryUSD, Length: 88883, dtype: float64

# %%
df['Hobbyist']
# Out:
# Respondent
# 1        Yes
# 2         No
# 3        Yes
# 4         No
# 5        Yes
#         ...
# 88377    Yes
# 88601     No
# 88802     No
# 88816     No
# 88863    Yes
# Name: Hobbyist, Length: 88883, dtype: object

# %%
df['Hobbyist'].map({'Yes' : True , 'No' : False})
# Out:
# Respondent
# 1         True
# 2        False
# 3         True
# 4        False
# 5         True
#          ...
# 88377     True
# 88601    False
# 88802    False
# 88816    False
# 88863     True
# Name: Hobbyist, Length: 88883, dtype: bool

# %%
df['Hobbyist']= df['Hobbyist'].map({'Yes' : True , 'No' : False})   #no inplace argument for map
df.head()
# Out:
#                                                    MainBranch  Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      True
# 2                      I am a student who is learning to code     False
# 3           I am not primarily a developer, but I write co...      True
# 4                              I am a developer by profession     False
# 5                              I am a developer by profession      True
#
#                            OpenSourcer  \
# Respondent
# 1                                Never
# 2              Less than once per year
# 3                                Never
# 4                                Never
# 5           Once a month or more often
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
# 3           The quality of OSS and closed source software ...
# ...

# %%
#ADD / REMOVE COLUMNS

# %%
#--Example--

# %%
#Columns

# %%
df1
# Out:
#                 email     first         last
# 0     lasya@gmail.com     kutti   naramgaris
# 1      janu@gmail.com   jahnavi  guntimadugu
# 2  prasanna@gmail.com  prasanna     nandigam
# 3     aishu@gmail.com     aishu   buddharaju
# 4       sai@gmail.com       sai    naramgari

# %%
df1['first'] + ' ' + df1['last']
# Out:
# 0       kutti naramgaris
# 1    jahnavi guntimadugu
# 2      prasanna nandigam
# 3       aishu buddharaju
# 4          sai naramgari
# dtype: object

# %%
df1['full-name'] = df1['first'] + ' ' + df1['last']
df1
# Out:
#                 email     first         last            full-name
# 0     lasya@gmail.com     kutti   naramgaris     kutti naramgaris
# 1      janu@gmail.com   jahnavi  guntimadugu  jahnavi guntimadugu
# 2  prasanna@gmail.com  prasanna     nandigam    prasanna nandigam
# 3     aishu@gmail.com     aishu   buddharaju     aishu buddharaju
# 4       sai@gmail.com       sai    naramgari        sai naramgari

# %%
df1.drop(columns = ['first','last'] ,inplace = True)  #to make it permanent use inplace

# %%
df1
# Out:
#                 email            full-name
# 0     lasya@gmail.com     kutti naramgaris
# 1      janu@gmail.com  jahnavi guntimadugu
# 2  prasanna@gmail.com    prasanna nandigam
# 3     aishu@gmail.com     aishu buddharaju
# 4       sai@gmail.com        sai naramgari

# %%
#to reverse it to two columns
df1['full-name'].str.split(' ')
# Out:
# 0       [kutti, naramgaris]
# 1    [jahnavi, guntimadugu]
# 2      [prasanna, nandigam]
# 3       [aishu, buddharaju]
# 4          [sai, naramgari]
# Name: full-name, dtype: object

# %%
df1['full-name'].str.split(' ' , expand = True)
# Out:
#           0            1
# 0     kutti   naramgaris
# 1   jahnavi  guntimadugu
# 2  prasanna     nandigam
# 3     aishu   buddharaju
# 4       sai    naramgari

# %%
df1[['first','last']] = df1['full-name'].str.split(' ' , expand = True)

# %%
df1
# Out:
#                 email            full-name     first         last
# 0     lasya@gmail.com     kutti naramgaris     kutti   naramgaris
# 1      janu@gmail.com  jahnavi guntimadugu   jahnavi  guntimadugu
# 2  prasanna@gmail.com    prasanna nandigam  prasanna     nandigam
# 3     aishu@gmail.com     aishu buddharaju     aishu   buddharaju
# 4       sai@gmail.com        sai naramgari       sai    naramgari

# %%
#Rows

# %%
df1._append({'first':'nani'},ignore_index = True)  #new version doesn't have append , so use _append - lol
# Out:
#                 email            full-name     first         last
# 0     lasya@gmail.com     kutti naramgaris     kutti   naramgaris
# 1      janu@gmail.com  jahnavi guntimadugu   jahnavi  guntimadugu
# 2  prasanna@gmail.com    prasanna nandigam  prasanna     nandigam
# 3     aishu@gmail.com     aishu buddharaju     aishu   buddharaju
# 4       sai@gmail.com        sai naramgari       sai    naramgari
# 5                 NaN                  NaN      nani          NaN

# %%
people = {
    "first" : ["bhane", "suji"],
    "last" : ["naramgari", "gedi",],
    "email" : ["bhanua@gmail.com","suji@gmail.com"]
}
df2 = pd.DataFrame(people)

# %%
df2
# Out:
#    first       last             email
# 0  bhane  naramgari  bhanua@gmail.com
# 1   suji       gedi    suji@gmail.com

# %%
df1._append(df2 , ignore_index= True )
# Out:
#                 email            full-name     first         last
# 0     lasya@gmail.com     kutti naramgaris     kutti   naramgaris
# 1      janu@gmail.com  jahnavi guntimadugu   jahnavi  guntimadugu
# 2  prasanna@gmail.com    prasanna nandigam  prasanna     nandigam
# 3     aishu@gmail.com     aishu buddharaju     aishu   buddharaju
# 4       sai@gmail.com        sai naramgari       sai    naramgari
# 5    bhanua@gmail.com                  NaN     bhane    naramgari
# 6      suji@gmail.com                  NaN      suji         gedi

# %%
df3 = df1._append(df2 , ignore_index= True ) #to make it permanent , there is no inplace so we use this

# %%
df3
# Out:
#                 email            full-name     first         last
# 0     lasya@gmail.com     kutti naramgaris     kutti   naramgaris
# 1      janu@gmail.com  jahnavi guntimadugu   jahnavi  guntimadugu
# 2  prasanna@gmail.com    prasanna nandigam  prasanna     nandigam
# 3     aishu@gmail.com     aishu buddharaju     aishu   buddharaju
# 4       sai@gmail.com        sai naramgari       sai    naramgari
# 5    bhanua@gmail.com                  NaN     bhane    naramgari
# 6      suji@gmail.com                  NaN      suji         gedi

# %%
#Remove
df3.drop(index = 4)
# Out:
#                 email            full-name     first         last
# 0     lasya@gmail.com     kutti naramgaris     kutti   naramgaris
# 1      janu@gmail.com  jahnavi guntimadugu   jahnavi  guntimadugu
# 2  prasanna@gmail.com    prasanna nandigam  prasanna     nandigam
# 3     aishu@gmail.com     aishu buddharaju     aishu   buddharaju
# 5    bhanua@gmail.com                  NaN     bhane    naramgari
# 6      suji@gmail.com                  NaN      suji         gedi

# %%
df3.drop(index = df3[df3['last'] == 'naramgari'].index)
# Out:
#                 email            full-name     first         last
# 0     lasya@gmail.com     kutti naramgaris     kutti   naramgaris
# 1      janu@gmail.com  jahnavi guntimadugu   jahnavi  guntimadugu
# 2  prasanna@gmail.com    prasanna nandigam  prasanna     nandigam
# 3     aishu@gmail.com     aishu buddharaju     aishu   buddharaju
# 6      suji@gmail.com                  NaN      suji         gedi

# %%
filt = df3['last'] == 'naramgari'
df3.drop(index = df3[filt].index)
# Out:
#                 email            full-name     first         last
# 0     lasya@gmail.com     kutti naramgaris     kutti   naramgaris
# 1      janu@gmail.com  jahnavi guntimadugu   jahnavi  guntimadugu
# 2  prasanna@gmail.com    prasanna nandigam  prasanna     nandigam
# 3     aishu@gmail.com     aishu buddharaju     aishu   buddharaju
# 6      suji@gmail.com                  NaN      suji         gedi

# %%
#SORTING

# %%
#--Example--

# %%
df1
# Out:
#                 email            full-name     first         last
# 0     lasya@gmail.com     kutti naramgaris     kutti   naramgaris
# 1      janu@gmail.com  jahnavi guntimadugu   jahnavi  guntimadugu
# 2  prasanna@gmail.com    prasanna nandigam  prasanna     nandigam
# 3     aishu@gmail.com     aishu buddharaju     aishu   buddharaju
# 4       sai@gmail.com        sai naramgari       sai    naramgari

# %%
df1.sort_values(by='last') #sortes by last name in ascending order
# Out:
#                 email            full-name     first         last
# 3     aishu@gmail.com     aishu buddharaju     aishu   buddharaju
# 1      janu@gmail.com  jahnavi guntimadugu   jahnavi  guntimadugu
# 2  prasanna@gmail.com    prasanna nandigam  prasanna     nandigam
# 4       sai@gmail.com        sai naramgari       sai    naramgari
# 0     lasya@gmail.com     kutti naramgaris     kutti   naramgaris

# %%
df1.sort_values(by='last',ascending=False)  #in descending order
# Out:
#                 email            full-name     first         last
# 0     lasya@gmail.com     kutti naramgaris     kutti   naramgaris
# 4       sai@gmail.com        sai naramgari       sai    naramgari
# 2  prasanna@gmail.com    prasanna nandigam  prasanna     nandigam
# 1      janu@gmail.com  jahnavi guntimadugu   jahnavi  guntimadugu
# 3     aishu@gmail.com     aishu buddharaju     aishu   buddharaju

# %%
 df1.sort_values(by=['last','first'],ascending=False) #for first name if we have same values it attempt sort for those
# Out:
#                 email            full-name     first         last
# 0     lasya@gmail.com     kutti naramgaris     kutti   naramgaris
# 4       sai@gmail.com        sai naramgari       sai    naramgari
# 2  prasanna@gmail.com    prasanna nandigam  prasanna     nandigam
# 1      janu@gmail.com  jahnavi guntimadugu   jahnavi  guntimadugu
# 3     aishu@gmail.com     aishu buddharaju     aishu   buddharaju

# %%
 df1.sort_values(by=['last','first'],ascending= [False,True] , inplace = True)

# %%
df1
# Out:
#                 email            full-name     first         last
# 0     lasya@gmail.com     kutti naramgaris     kutti   naramgaris
# 4       sai@gmail.com        sai naramgari       sai    naramgari
# 2  prasanna@gmail.com    prasanna nandigam  prasanna     nandigam
# 1      janu@gmail.com  jahnavi guntimadugu   jahnavi  guntimadugu
# 3     aishu@gmail.com     aishu buddharaju     aishu   buddharaju

# %%
df1.sort_index()  #to get the original ones
# Out:
#                 email            full-name     first         last
# 0     lasya@gmail.com     kutti naramgaris     kutti   naramgaris
# 1      janu@gmail.com  jahnavi guntimadugu   jahnavi  guntimadugu
# 2  prasanna@gmail.com    prasanna nandigam  prasanna     nandigam
# 3     aishu@gmail.com     aishu buddharaju     aishu   buddharaju
# 4       sai@gmail.com        sai naramgari       sai    naramgari

# %%
df1['last'].sort_values()
# Out:
# 3     buddharaju
# 1    guntimadugu
# 2       nandigam
# 4      naramgari
# 0     naramgaris
# Name: last, dtype: object

# %%
#--Main--

# %%
df.head()
# Out:
#                                                    MainBranch  Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      True
# 2                      I am a student who is learning to code     False
# 3           I am not primarily a developer, but I write co...      True
# 4                              I am a developer by profession     False
# 5                              I am a developer by profession      True
#
#                            OpenSourcer  \
# Respondent
# 1                                Never
# 2              Less than once per year
# 3                                Never
# 4                                Never
# 5           Once a month or more often
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
# 3           The quality of OSS and closed source software ...
# ...

# %%
df.sort_values(by = ['Country','SalaryUSD'],ascending= [True,False] , inplace = True)

# %%
df[['Country','SalaryUSD']].head(50)
# Out:
#                 Country  SalaryUSD
# Respondent
# 63129       Afghanistan  1000000.0
# 50499       Afghanistan   153216.0
# 39258       Afghanistan    19152.0
# 58450       Afghanistan    17556.0
# 7085        Afghanistan    14364.0
# 22450       Afghanistan     7980.0
# 48436       Afghanistan     4464.0
# 10746       Afghanistan     3996.0
# 8149        Afghanistan     1596.0
# 29736       Afghanistan     1116.0
# 722         Afghanistan        0.0
# 28638       Afghanistan        0.0
# 6417        Afghanistan        NaN
# 7353        Afghanistan        NaN
# 12310       Afghanistan        NaN
# 26340       Afghanistan        NaN
# 29045       Afghanistan        NaN
# 33178       Afghanistan        NaN
# 37802       Afghanistan        NaN
# 40000       Afghanistan        NaN
# 43106       Afghanistan        NaN
# 44403       Afghanistan        NaN
# 45854       Afghanistan        NaN
# 47110       Afghanistan        NaN
# 49702       Afghanistan        NaN
# ...

# %%
df['SalaryUSD'].nlargest(10) #to get only one column
# Out:
# Respondent
# 25983    2000000.0
# 87896    2000000.0
# 22013    2000000.0
# 28243    2000000.0
# 72732    2000000.0
# 78151    2000000.0
# 80200    2000000.0
# 52132    2000000.0
# 75561    2000000.0
# 32250    2000000.0
# Name: SalaryUSD, dtype: float64

# %%
df.nlargest(10,'SalaryUSD')  #to get all the data
# Out:
#                                                    MainBranch  Hobbyist  \
# Respondent
# 25983                          I am a developer by profession      True
# 87896                          I am a developer by profession      True
# 22013                          I am a developer by profession      True
# 28243                          I am a developer by profession      True
# 72732       I am not primarily a developer, but I write co...     False
# 78151                          I am a developer by profession      True
# 80200                          I am a developer by profession      True
# 52132                          I am a developer by profession      True
# 75561                          I am a developer by profession      True
# 32250                          I am a developer by profession      True
#
#                                                   OpenSourcer  \
# Respondent
# 25983                                 Less than once per year
# ...

# %%
df.nsmallest(10,'SalaryUSD')
# Out:
#                                                    MainBranch  Hobbyist  \
# Respondent
# 722                            I am a developer by profession     False
# 28638                          I am a developer by profession      True
# 13825                          I am a developer by profession      True
# 40913                          I am a developer by profession      True
# 30630                          I am a developer by profession      True
# 69049                          I am a developer by profession     False
# 19340       I am not primarily a developer, but I write co...      True
# 16214       I am not primarily a developer, but I write co...      True
# 29355                          I am a developer by profession      True
# 1685                           I am a developer by profession      True
#
#                                                   OpenSourcer  \
# Respondent
# 722         Less than once a month but more than once per ...
# ...

# %%
#GROUPING AND AGGREGATING

# %%
df.head()  #reload again for respondent to be the index
# Out:
#                                                    MainBranch  Hobbyist  \
# Respondent
# 63129                          I am a developer by profession      True
# 50499       I am not primarily a developer, but I write co...      True
# 39258                          I am a developer by profession      True
# 58450                          I am a developer by profession      True
# 7085                           I am a developer by profession      True
#
#                         OpenSourcer  \
# Respondent
# 63129                         Never
# 50499       Less than once per year
# 39258       Less than once per year
# 58450                         Never
# 7085        Less than once per year
#
#                                                    OpenSource  \
# Respondent
# 63129       OSS is, on average, of HIGHER quality than pro...
# 50499       OSS is, on average, of LOWER quality than prop...
# 39258       OSS is, on average, of LOWER quality than prop...
# ...

# %%
df['SalaryUSD'].head(15)
# Out:
# Respondent
# 63129    1000000.0
# 50499     153216.0
# 39258      19152.0
# 58450      17556.0
# 7085       14364.0
# 22450       7980.0
# 48436       4464.0
# 10746       3996.0
# 8149        1596.0
# 29736       1116.0
# 722            0.0
# 28638          0.0
# 6417           NaN
# 7353           NaN
# 12310          NaN
# Name: SalaryUSD, dtype: float64

# %%
df['SalaryUSD'].median()  #to check median for the column by ignoring na values
# Out:
# 57287.0

# %%
df.median()

# %%
df.describe()   #count - non na rows , 50% - median
# Out:
#           CompTotal  ConvertedComp   WorkWeekHrs    CodeRevHrs           Age
# count  5.594500e+04   5.582300e+04  64503.000000  49790.000000  79210.000000
# mean   5.519014e+11   1.271107e+05     42.127197      5.084308     30.336699
# std    7.331926e+13   2.841523e+05     37.287610      5.513931      9.178390
# min    0.000000e+00   0.000000e+00      1.000000      0.000000      1.000000
# 25%    2.000000e+04   2.577750e+04     40.000000      2.000000     24.000000
# 50%    6.200000e+04   5.728700e+04     40.000000      4.000000     29.000000
# 75%    1.200000e+05   1.000000e+05     44.750000      6.000000     35.000000
# max    1.000000e+16   2.000000e+06   4850.000000     99.000000     99.000000

# %%
df['SalaryUSD'].count()

# %%
df['Hobbyist']
# Out:
# Respondent
# 1        Yes
# 2         No
# 3        Yes
# 4         No
# 5        Yes
#         ...
# 88377    Yes
# 88601     No
# 88802     No
# 88816     No
# 88863    Yes
# Name: Hobbyist, Length: 88883, dtype: object

# %%
df['Hobbyist'].value_counts()
# Out:
# Hobbyist
# Yes    71257
# No     17626
# Name: count, dtype: int64

# %%
df['SocialMedia']
# Out:
# Respondent
# 1          Twitter
# 2        Instagram
# 3           Reddit
# 4           Reddit
# 5         Facebook
#            ...
# 88377      YouTube
# 88601          NaN
# 88802          NaN
# 88816          NaN
# 88863     WhatsApp
# Name: SocialMedia, Length: 88883, dtype: object

# %%
schema_df.loc['SocialMedia']
# Out:
# QuestionText    What social media site do you use the most?
# Name: SocialMedia, dtype: object

# %%
df['SocialMedia'].value_counts()
# Out:
# SocialMedia
# Reddit                      14374
# YouTube                     13830
# WhatsApp                    13347
# Facebook                    13178
# Twitter                     11398
# Instagram                    6261
# I don't use social media     5554
# LinkedIn                     4501
# WeChat 微信                     667
# Snapchat                      628
# VK ВКонта́кте                 603
# Weibo 新浪微博                     56
# Youku Tudou 优酷                 21
# Hello                          19
# Name: count, dtype: int64

# %%
df['SocialMedia'].value_counts(normalize=True)
# Out:
# SocialMedia
# Reddit                      0.170233
# YouTube                     0.163791
# WhatsApp                    0.158071
# Facebook                    0.156069
# Twitter                     0.134988
# Instagram                   0.074150
# I don't use social media    0.065777
# LinkedIn                    0.053306
# WeChat 微信                   0.007899
# Snapchat                    0.007437
# VK ВКонта́кте               0.007141
# Weibo 新浪微博                  0.000663
# Youku Tudou 优酷              0.000249
# Hello                       0.000225
# Name: proportion, dtype: float64

# %%
#Grouping--to check results based on certain columns

# %%
#groupby - split, apply function , combinen results

# %%
df['Country'].value_counts()
# Out:
# Country
# United States        20949
# India                 9061
# Germany               5866
# United Kingdom        5737
# Canada                3395
#                      ...
# Tonga                    1
# Timor-Leste              1
# North Korea              1
# Brunei Darussalam        1
# Chad                     1
# Name: count, Length: 179, dtype: int64

# %%
country_grp = df.groupby(['Country'])

# %%
country_grp

# %%
country_grp.get_group('India')
# Out:
#                                         MainBranch Hobbyist  \
# Respondent
# 8                      I code primarily as a hobby      Yes
# 10                  I am a developer by profession      Yes
# 15          I am a student who is learning to code      Yes
# 50                  I am a developer by profession      Yes
# 65                  I am a developer by profession      Yes
# ...                                            ...      ...
# 77339                                          NaN      Yes
# 79795                                          NaN      Yes
# 83862                                          NaN      Yes
# 84299                                          NaN      Yes
# 86012                                          NaN      Yes
#
#                                                   OpenSourcer  \
# Respondent
# 8                                     Less than once per year
# 10                                 Once a month or more often
# ...

# %%
filt = df['Country'] == 'India'
df.loc[filt]
# Out:
#                                         MainBranch Hobbyist  \
# Respondent
# 8                      I code primarily as a hobby      Yes
# 10                  I am a developer by profession      Yes
# 15          I am a student who is learning to code      Yes
# 50                  I am a developer by profession      Yes
# 65                  I am a developer by profession      Yes
# ...                                            ...      ...
# 77339                                          NaN      Yes
# 79795                                          NaN      Yes
# 83862                                          NaN      Yes
# 84299                                          NaN      Yes
# 86012                                          NaN      Yes
#
#                                                   OpenSourcer  \
# Respondent
# 8                                     Less than once per year
# 10                                 Once a month or more often
# ...

# %%
df.loc[filt]['SocialMedia'].value_counts()
# Out:
# SocialMedia
# WhatsApp                    2990
# YouTube                     1820
# LinkedIn                     955
# Facebook                     841
# Instagram                    822
# Twitter                      542
# Reddit                       473
# I don't use social media     250
# Snapchat                      23
# Hello                          5
# WeChat 微信                      5
# VK ВКонта́кте                  4
# Youku Tudou 优酷                 2
# Weibo 新浪微博                     1
# Name: count, dtype: int64

# %%
country_grp['SocialMedia'].value_counts().head(50)
# Out:
# Country              SocialMedia
# Afghanistan          Facebook                     15
#                      YouTube                       9
#                      I don't use social media      6
#                      WhatsApp                      4
#                      Instagram                     1
#                      LinkedIn                      1
#                      Twitter                       1
# Albania              WhatsApp                     18
#                      Facebook                     16
#                      Instagram                    13
#                      YouTube                      10
#                      Twitter                       8
#                      LinkedIn                      7
#                      Reddit                        6
#                      I don't use social media      4
#                      Snapchat                      1
#                      WeChat 微信                     1
# ...

# %%
country_grp['SocialMedia'].value_counts().loc['India']
# Out:
# SocialMedia
# WhatsApp                    2990
# YouTube                     1820
# LinkedIn                     955
# Facebook                     841
# Instagram                    822
# Twitter                      542
# Reddit                       473
# I don't use social media     250
# Snapchat                      23
# Hello                          5
# WeChat 微信                      5
# VK ВКонта́кте                  4
# Youku Tudou 优酷                 2
# Weibo 新浪微博                     1
# Name: count, dtype: int64

# %%
country_grp['SalaryUSD'].median()

# %%
country_grp['SalaryUSD'].median().loc['Germany']

# %%
country_grp['SalaryUSD'].agg(['median','mean'])    #Aggregation

# %%
country_grp['SalaryUSD'].agg(['median','mean']).loc['Canada']

# %%
filt = df['Country'] == 'India'
df.loc[filt]['LanguageWorkedWith']
# Out:
# Respondent
# 8        Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
# 10                           C#;Go;JavaScript;Python;R;SQL
# 15       Assembly;Bash/Shell/PowerShell;C;C++;HTML/CSS;...
# 50       Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
# 65                         Assembly;C;C++;C#;HTML/CSS;Java
#                                ...
# 77339                                            Other(s):
# 79795                 Bash/Shell/PowerShell;Python;SQL;VBA
# 83862    Assembly;C;C++;HTML/CSS;Java;JavaScript;Object...
# 84299     HTML/CSS;Java;JavaScript;Python;Swift;TypeScript
# 86012        Bash/Shell/PowerShell;C++;HTML/CSS;JavaScript
# Name: LanguageWorkedWith, Length: 9061, dtype: object

# %%
df.loc[filt]['LanguageWorkedWith'].str.contains('Python')
# Out:
# Respondent
# 8         True
# 10        True
# 15       False
# 50        True
# 65       False
#          ...
# 77339    False
# 79795     True
# 83862    False
# 84299     True
# 86012    False
# Name: LanguageWorkedWith, Length: 9061, dtype: object

# %%
df.loc[filt]['LanguageWorkedWith'].str.contains('Python').sum()
# Out:
# 3105

# %%
country_grp['LanguageWorkedWith'].str.contains('Python').sum()

# %%
#we use apply method for above error
country_grp['LanguageWorkedWith'].apply(lambda x :x.str.contains('Python').sum())

# %%
country_respondents = df['Country'].value_counts()
country_respondents

# %%
country_uses_python = country_grp['LanguageWorkedWith'].apply(lambda x :x.str.contains('Python').sum())
country_uses_python
# Out:
# Country
# Afghanistan                              8
# Albania                                 23
# Algeria                                 40
# Andorra                                  0
# Angola                                   2
#                                         ..
# Venezuela, Bolivarian Republic of...    28
# Viet Nam                                78
# Yemen                                    3
# Zambia                                   4
# Zimbabwe                                14
# Name: LanguageWorkedWith, Length: 179, dtype: int64

# %%
python_df = pd.concat([country_respondents,country_uses_python],axis = 'columns')
python_df

# %%
python_df.rename(columns = {'count' : 'NumRespondents', 'LanguageWorkedWith' : 'NumKnowsPython'},inplace = True)
python_df

# %%
python_df['PctKnowsPython'] = (python_df['NumKnowsPython']/python_df['NumRespondents'])*100
python_d

# %%
python_df.sort_values(by = 'PctKnowsPython' , ascending = False , inplace = True)
python_df.head(50)

# %%
python_df.loc['Japan']

# %%
#CLEANING DATA

# %%
#Example--

# %%
import numpy as np
people = {
    "first" : ["lasya", "janu", "prasu","aishu","sai",np.nan,None,'NA'],
    "last" : ["naramgari", "guntimadugu","nandigam","buddharaju","naramgari",np.nan,np.nan,'Missing'],
    "email" : ["lasya@gmail.com","janu@gmail.com","prasu@gmail.com","aishu@gmail.com","sai@gmail.com",None,np.nan,'Anonymous@gmail.com'],
    "age" : ["19" ,"18","21","20", None,None, None ,'Missing'],
}

# %%
df1 = pd.DataFrame(people)
df1.replace('NA',np.nan,inplace = True)
df1.replace('Missing',np.nan,inplace = True)

# %%
df1
# Out:
#    first         last                email   age
# 0  lasya    naramgari      lasya@gmail.com    19
# 1   janu  guntimadugu       janu@gmail.com    18
# 2  prasu     nandigam      prasu@gmail.com    21
# 3  aishu   buddharaju      aishu@gmail.com    20
# 4    sai    naramgari        sai@gmail.com  None
# 5    NaN          NaN                 None  None
# 6   None          NaN                  NaN  None
# 7    NaN          NaN  Anonymous@gmail.com   NaN

# %%
df1.dropna()
# Out:
#    first         last            email age
# 0  lasya    naramgari  lasya@gmail.com  19
# 1   janu  guntimadugu   janu@gmail.com  18
# 2  prasu     nandigam  prasu@gmail.com  21
# 3  aishu   buddharaju  aishu@gmail.com  20

# %%
df1.dropna(axis= 'index', how='any')   #should get same results as above
# Out:
#    first         last            email age
# 0  lasya    naramgari  lasya@gmail.com  19
# 1   janu  guntimadugu   janu@gmail.com  18
# 2  prasu     nandigam  prasu@gmail.com  21
# 3  aishu   buddharaju  aishu@gmail.com  20

# %%
df1.dropna(axis= 'index', how='all')  #keep rows with some missign values , all should be missing for the row to drop
# Out:
#    first         last                email   age
# 0  lasya    naramgari      lasya@gmail.com    19
# 1   janu  guntimadugu       janu@gmail.com    18
# 2  prasu     nandigam      prasu@gmail.com    21
# 3  aishu   buddharaju      aishu@gmail.com    20
# 4    sai    naramgari        sai@gmail.com  None
# 7    NaN          NaN  Anonymous@gmail.com   NaN

# %%
df1.dropna(axis= 'columns', how='all')
# Out:
#    first         last                email   age
# 0  lasya    naramgari      lasya@gmail.com    19
# 1   janu  guntimadugu       janu@gmail.com    18
# 2  prasu     nandigam      prasu@gmail.com    21
# 3  aishu   buddharaju      aishu@gmail.com    20
# 4    sai    naramgari        sai@gmail.com  None
# 5    NaN          NaN                 None  None
# 6   None          NaN                  NaN  None
# 7    NaN          NaN  Anonymous@gmail.com   NaN

# %%
df1.dropna(axis= 'columns', how='any') #a row completely has missing value so df is empty
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3, 4, 5, 6, 7]

# %%
df1.dropna(axis= 'index', how='any',subset=['email'])#missing values for email is remved even if we use all or any
# Out:
#    first         last                email   age
# 0  lasya    naramgari      lasya@gmail.com    19
# 1   janu  guntimadugu       janu@gmail.com    18
# 2  prasu     nandigam      prasu@gmail.com    21
# 3  aishu   buddharaju      aishu@gmail.com    20
# 4    sai    naramgari        sai@gmail.com  None
# 7    NaN          NaN  Anonymous@gmail.com   NaN

# %%
df1.dropna(axis= 'index', how='any',subset=['last','email'])
# Out:
#    first         last            email   age
# 0  lasya    naramgari  lasya@gmail.com    19
# 1   janu  guntimadugu   janu@gmail.com    18
# 2  prasu     nandigam  prasu@gmail.com    21
# 3  aishu   buddharaju  aishu@gmail.com    20
# 4    sai    naramgari    sai@gmail.com  None

# %%
df1.dropna(axis= 'index', how='all',subset=['last','email'])
# Out:
#    first         last                email   age
# 0  lasya    naramgari      lasya@gmail.com    19
# 1   janu  guntimadugu       janu@gmail.com    18
# 2  prasu     nandigam      prasu@gmail.com    21
# 3  aishu   buddharaju      aishu@gmail.com    20
# 4    sai    naramgari        sai@gmail.com  None
# 7    NaN          NaN  Anonymous@gmail.com   NaN

# %%
df1.isna()
# Out:
#    first   last  email    age
# 0  False  False  False  False
# 1  False  False  False  False
# 2  False  False  False  False
# 3  False  False  False  False
# 4  False  False  False   True
# 5   True   True   True   True
# 6   True   True   True   True
# 7   True   True  False   True

# %%
df1.fillna(0)
# Out:
#    first         last                email age
# 0  lasya    naramgari      lasya@gmail.com  19
# 1   janu  guntimadugu       janu@gmail.com  18
# 2  prasu     nandigam      prasu@gmail.com  21
# 3  aishu   buddharaju      aishu@gmail.com  20
# 4    sai    naramgari        sai@gmail.com   0
# 5      0            0                    0   0
# 6      0            0                    0   0
# 7      0            0  Anonymous@gmail.com   0

# %%
#CASTING DATATYPES

# %%
df1.dtypes
# Out:
# first    object
# last     object
# email    object
# age      object
# dtype: object

# %%
df1['age'].mean()  #error because its str , not int
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[260], line 1
# ----> 1 df1['age'].mean()  #error because its str , not int
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\series.py:6221, in Series.mean(self, axis, skipna, numeric_only, **kwargs)
#    6213 @doc(make_doc("mean", ndim=1))
#    6214 def mean(
#    6215     self,
#    (...)
#    6219     **kwargs,
#    6220 ):
# -> 6221     return NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\generic.py:11984, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   11977 def mean(
#   11978     self,
#   11979     axis: Axis | None = 0,
#    (...)
# ...

# %%
type(np.nan)

# %%
df1['age'] = df1['age'].astype(int)  #error because nan values are not str, they are float
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[261], line 1
# ----> 1 df1['age'] = df1['age'].astype(int)  #error because nan values are not str, they are float
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\generic.py:6534, in NDFrame.astype(self, dtype, copy, errors)
#    6530     results = [ser.astype(dtype, copy=copy) for _, ser in self.items()]
#    6532 else:
#    6533     # else, only a single dtype is given
# -> 6534     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6535     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6536     return res.__finalize__(self, method="astype")
#
# ...

# %%
df1['age'] = df1['age'].astype(float)

# %%
df1.dtypes
# Out:
# first    object
# last     object
# email    object
# age      object
# dtype: object

# %%
df1['age'].mean()

# %%
#Main--

# %%
na_vals = ['NA','Missing']
df = pd.read_csv('data/survey_results_public.csv',index_col='Respondent',na_values = na_vals) #not change much as the data is already good

# %%
df.head()
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
#
#                            OpenSourcer  \
# Respondent
# 1                                Never
# 2              Less than once per year
# 3                                Never
# 4                                Never
# 5           Once a month or more often
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
# 3           The quality of OSS and closed source software ...
# ...

# %%
df['YearsCode'].head(10)
# Out:
# Respondent
# 1       4
# 2     NaN
# 3       3
# 4       3
# 5      16
# 6      13
# 7       6
# 8       8
# 9      12
# 10     12
# Name: YearsCode, dtype: object

# %%
df['YearsCode'].mean() #error

# %%
df['YearsCode'] = df['YearsCode'].astype(float)

# %%
df['YearsCode'].unique()
# Out:
# array(['4', nan, '3', '16', '13', '6', '8', '12', '2', '5', '17', '10',
#        '14', '35', '7', 'Less than 1 year', '30', '9', '26', '40', '19',
#        '15', '20', '28', '25', '1', '22', '11', '33', '50', '41', '18',
#        '34', '24', '23', '42', '27', '21', '36', '32', '39', '38', '31',
#        '37', 'More than 50 years', '29', '44', '45', '48', '46', '43',
#        '47', '49'], dtype=object)

# %%
df['YearsCode'].replace('Less than 1 year',0,inplace=True)

# %%
df['YearsCode'].replace('More than 50 years',51,inplace=True)

# %%
df['YearsCode'] = df['YearsCode'].astype(float)  #no error

# %%
df['YearsCode'].mean()
# Out:
# 11.662114216834588

# %%
df['YearsCode'].median()
# Out:
# 9.0

# %%
#DATE TIME series data

# %%
dfs = pd.read_csv('data/ETH_1H.csv')


#if dates are not formatted the use this
#d_parser = lamda x: pd.datetime.strptime(x ,'%Y-%m-%d %I-%p'  ) -- str to time format
#df = pd.read_csv('data/ETH_1H.csv', parse_dates = ['Date'], data_parsed = d_parser )

# %%
dfs.head()

# %%
dfs.loc[0,'Date']

# %%
dfs.loc[0,'Date'].day_name()

# %%
dfs['Date'] = pd.to_datetime(dfs['Date']  )
#if it is not in format we may get erro then we can use
#--> df['Date'] = pd.to_datetime(df['Date'] , format= '%Y-%m-%d %I-%p' )

# %%
dfs['Date']
# Out:
# 0       2020-04-16 00:00:00
# 1       2020-04-15 23:00:00
# 2       2020-04-15 22:00:00
# 3       2020-04-15 21:00:00
# 4       2020-04-15 20:00:00
#                 ...
# 34492   2016-05-09 17:00:00
# 34493   2016-05-09 16:00:00
# 34494   2016-05-09 15:00:00
# 34495   2016-05-09 14:00:00
# 34496   2016-05-09 13:00:00
# Name: Date, Length: 34497, dtype: datetime64[ns]

# %%
dfs.loc[0,'Date'].day_name()  
#now it doesn't give error as above as we converted it
# Out:
# 'Thursday'

# %%
dfs['Date'].dt.day_name()   #dayname for all values
# Out:
# 0         Thursday
# 1        Wednesday
# 2        Wednesday
# 3        Wednesday
# 4        Wednesday
#            ...
# 34492       Monday
# 34493       Monday
# 34494       Monday
# 34495       Monday
# 34496       Monday
# Name: Date, Length: 34497, dtype: object

# %%
dfs['DayOfWeek'] = dfs['Date'].dt.day_name()

# %%
dfs
# Out:
#        Unix Timestamp                Date  Symbol    Open    High     Low  \
# 0       1586995200000 2020-04-16 00:00:00  ETHUSD  152.94  152.94  150.39
# 1       1586991600000 2020-04-15 23:00:00  ETHUSD  155.81  155.81  151.39
# 2       1586988000000 2020-04-15 22:00:00  ETHUSD  157.18  157.30  155.32
# 3       1586984400000 2020-04-15 21:00:00  ETHUSD  158.04  158.31  157.16
# 4       1586980800000 2020-04-15 20:00:00  ETHUSD  157.10  158.10  156.87
# ...               ...                 ...     ...     ...     ...     ...
# 34492      1462813200 2016-05-09 17:00:00  ETHUSD    9.83    9.83    9.48
# 34493      1462809600 2016-05-09 16:00:00  ETHUSD    9.99    9.99    9.79
# 34494      1462806000 2016-05-09 15:00:00  ETHUSD   10.00   10.00    9.99
# 34495      1462802400 2016-05-09 14:00:00  ETHUSD    9.55   10.00    9.55
# 34496      1462798800 2016-05-09 13:00:00  ETHUSD    0.00   12.00    0.00
#
#         Close       Volume  DayOfWeek
# 0      150.39   650.188125   Thursday
# ...

# %%
dfs['Date'].min()  #earliest date
# Out:
# Timestamp('2016-05-09 13:00:00')

# %%
dfs['Date'].max()   #recent date
# Out:
# Timestamp('2020-04-16 00:00:00')

# %%
dfs['Date'].max() - dfs['Date'].min()  #time between them
# Out:
# Timedelta('1437 days 11:00:00')

# %%
filt = (dfs['Date'] >= '2020')
dfs.loc[filt]
# Out:
#       Unix Timestamp                Date  Symbol    Open    High     Low  \
# 0      1586995200000 2020-04-16 00:00:00  ETHUSD  152.94  152.94  150.39
# 1      1586991600000 2020-04-15 23:00:00  ETHUSD  155.81  155.81  151.39
# 2      1586988000000 2020-04-15 22:00:00  ETHUSD  157.18  157.30  155.32
# 3      1586984400000 2020-04-15 21:00:00  ETHUSD  158.04  158.31  157.16
# 4      1586980800000 2020-04-15 20:00:00  ETHUSD  157.10  158.10  156.87
# ...              ...                 ...     ...     ...     ...     ...
# 2540   1577851200000 2020-01-01 04:00:00  ETHUSD  129.83  129.96  129.13
# 2541   1577847600000 2020-01-01 03:00:00  ETHUSD  130.25  130.30  129.42
# 2542   1577844000000 2020-01-01 02:00:00  ETHUSD  129.95  130.58  129.95
# 2543   1577840400000 2020-01-01 01:00:00  ETHUSD  128.11  130.01  128.11
# 2544   1577836800000 2020-01-01 00:00:00  ETHUSD  128.84  128.84  128.07
#
#        Close       Volume  DayOfWeek
# 0     150.39   650.188125   Thursday
# ...

# %%
filt1 = (dfs['Date'] >= '2019') & (dfs['Date'] <'2020')
dfs.loc[filt1]
# Out:
#        Unix Timestamp                Date  Symbol    Open    High     Low  \
# 2545    1577833200000 2019-12-31 23:00:00  ETHUSD  128.68  128.85  127.82
# 2546    1577829600000 2019-12-31 22:00:00  ETHUSD  128.40  128.93  127.77
# 2547    1577826000000 2019-12-31 21:00:00  ETHUSD  127.87  128.41  127.81
# 2548    1577822400000 2019-12-31 20:00:00  ETHUSD  127.86  128.30  127.86
# 2549    1577818800000 2019-12-31 19:00:00  ETHUSD  128.78  128.78  127.86
# ...               ...                 ...     ...     ...     ...     ...
# 11297   1546315200000 2019-01-01 04:00:00  ETHUSD  130.83  133.75  130.83
# 11298   1546311600000 2019-01-01 03:00:00  ETHUSD  129.79  131.00  129.79
# 11299   1546308000000 2019-01-01 02:00:00  ETHUSD  130.98  130.98  129.25
# 11300   1546304400000 2019-01-01 01:00:00  ETHUSD  131.10  131.10  128.72
# 11301   1546300800000 2019-01-01 00:00:00  ETHUSD  130.80  131.70  130.00
#
#         Close       Volume DayOfWeek
# 2545   128.84   857.650259   Tuesday
# ...

# %%
filt1 = (dfs['Date'] >= pd.to_datetime('2019-01-01')) & (dfs['Date'] < pd.to_datetime('2020-01-01'))
dfs.loc[filt1]  #same as above
# Out:
#        Unix Timestamp                Date  Symbol    Open    High     Low  \
# 2545    1577833200000 2019-12-31 23:00:00  ETHUSD  128.68  128.85  127.82
# 2546    1577829600000 2019-12-31 22:00:00  ETHUSD  128.40  128.93  127.77
# 2547    1577826000000 2019-12-31 21:00:00  ETHUSD  127.87  128.41  127.81
# 2548    1577822400000 2019-12-31 20:00:00  ETHUSD  127.86  128.30  127.86
# 2549    1577818800000 2019-12-31 19:00:00  ETHUSD  128.78  128.78  127.86
# ...               ...                 ...     ...     ...     ...     ...
# 11297   1546315200000 2019-01-01 04:00:00  ETHUSD  130.83  133.75  130.83
# 11298   1546311600000 2019-01-01 03:00:00  ETHUSD  129.79  131.00  129.79
# 11299   1546308000000 2019-01-01 02:00:00  ETHUSD  130.98  130.98  129.25
# 11300   1546304400000 2019-01-01 01:00:00  ETHUSD  131.10  131.10  128.72
# 11301   1546300800000 2019-01-01 00:00:00  ETHUSD  130.80  131.70  130.00
#
#         Close       Volume DayOfWeek
# 2545   128.84   857.650259   Tuesday
# ...

# %%
dfs.set_index('Date',inplace = True)

# %%
dfs
# Out:
#                      Unix Timestamp  Symbol    Open    High     Low   Close  \
# Date
# 2020-04-16 00:00:00   1586995200000  ETHUSD  152.94  152.94  150.39  150.39
# 2020-04-15 23:00:00   1586991600000  ETHUSD  155.81  155.81  151.39  152.94
# 2020-04-15 22:00:00   1586988000000  ETHUSD  157.18  157.30  155.32  155.81
# 2020-04-15 21:00:00   1586984400000  ETHUSD  158.04  158.31  157.16  157.18
# 2020-04-15 20:00:00   1586980800000  ETHUSD  157.10  158.10  156.87  158.04
# ...                             ...     ...     ...     ...     ...     ...
# 2016-05-09 17:00:00      1462813200  ETHUSD    9.83    9.83    9.48    9.49
# 2016-05-09 16:00:00      1462809600  ETHUSD    9.99    9.99    9.79    9.83
# 2016-05-09 15:00:00      1462806000  ETHUSD   10.00   10.00    9.99    9.99
# 2016-05-09 14:00:00      1462802400  ETHUSD    9.55   10.00    9.55   10.00
# 2016-05-09 13:00:00      1462798800  ETHUSD    0.00   12.00    0.00    9.55
#
#                           Volume  DayOfWeek
# ...

# %%
dfs.loc['2019']  #as we changed date to index its easy now
# Out:
#                      Unix Timestamp  Symbol    Open    High     Low   Close  \
# Date
# 2019-12-31 23:00:00   1577833200000  ETHUSD  128.68  128.85  127.82  128.84
# 2019-12-31 22:00:00   1577829600000  ETHUSD  128.40  128.93  127.77  128.68
# 2019-12-31 21:00:00   1577826000000  ETHUSD  127.87  128.41  127.81  128.40
# 2019-12-31 20:00:00   1577822400000  ETHUSD  127.86  128.30  127.86  127.87
# 2019-12-31 19:00:00   1577818800000  ETHUSD  128.78  128.78  127.86  127.86
# ...                             ...     ...     ...     ...     ...     ...
# 2019-01-01 04:00:00   1546315200000  ETHUSD  130.83  133.75  130.83  132.09
# 2019-01-01 03:00:00   1546311600000  ETHUSD  129.79  131.00  129.79  130.83
# 2019-01-01 02:00:00   1546308000000  ETHUSD  130.98  130.98  129.25  129.79
# 2019-01-01 01:00:00   1546304400000  ETHUSD  131.10  131.10  128.72  130.98
# 2019-01-01 00:00:00   1546300800000  ETHUSD  130.80  131.70  130.00  131.10
#
#                           Volume DayOfWeek
# Date
# ...

# %%
#slicing
dfs.loc['2020-01' : '2020-02']

#check properly this error and slicing

# %%
dfs.loc['2020-01' : '2020-02']['Close'].mean()

# %%
dfs.loc['2020-01' : '2020-02'].head()

# %%
dfs.loc['2020-01']['Close'].mean()
# Out:
# 155.1329569892473

# %%
dfs.loc['2020-01-01']['High']  #high values of that day
# Out:
# Date
# 2020-01-01 23:00:00    130.25
# 2020-01-01 22:00:00    131.31
# 2020-01-01 21:00:00    131.92
# 2020-01-01 20:00:00    131.74
# 2020-01-01 19:00:00    131.71
# 2020-01-01 18:00:00    132.10
# 2020-01-01 17:00:00    132.57
# 2020-01-01 16:00:00    132.52
# 2020-01-01 15:00:00    131.86
# 2020-01-01 14:00:00    131.90
# 2020-01-01 13:00:00    131.59
# 2020-01-01 12:00:00    131.27
# 2020-01-01 11:00:00    131.46
# 2020-01-01 10:00:00    130.47
# 2020-01-01 09:00:00    130.23
# 2020-01-01 08:00:00    129.96
# 2020-01-01 07:00:00    130.35
# 2020-01-01 06:00:00    130.31
# 2020-01-01 05:00:00    129.92
# 2020-01-01 04:00:00    129.96
# 2020-01-01 03:00:00    130.30
# 2020-01-01 02:00:00    130.58
# 2020-01-01 01:00:00    130.01
# 2020-01-01 00:00:00    128.84
# Name: High, dtype: float64

# %%
dfs.loc['2020-01-01']['High'].max() #max of high values of that day
# Out:
# 132.57

# %%
#RESAMPLING

# %%
 dfs['High'].resample('D').max()

#D - day
#W - weely
#H - hourly and many other. check later
# Out:
# Date
# 2016-05-09     12.00
# 2016-05-10      9.96
# 2016-05-11     10.47
# 2016-05-12     12.00
# 2016-05-13     11.59
#                ...
# 2020-04-12    165.37
# 2020-04-13    159.51
# 2020-04-14    162.15
# 2020-04-15    161.52
# 2020-04-16    152.94
# Freq: D, Name: High, Length: 1439, dtype: float64

# %%
highs = dfs['High'].resample('D').max()

# %%
highs['2020-04-12']
# Out:
# 165.37

# %%
#plotting

# %%
#%matplotlib inline  - install it to check
#highs.plot()

# %%
#to resample multiple columns

# %%
dfs.resample('W').max()  #for entire df
# Out:
#             Unix Timestamp  Symbol    Open    High     Low   Close  \
# Date
# 2016-05-15      1463353200  ETHUSD   11.59   12.00   11.59   11.59
# 2016-05-22      1463958000  ETHUSD   14.75   14.77   14.75   14.75
# 2016-05-29      1464562800  ETHUSD   14.43   14.43   14.33   14.43
# 2016-06-05      1465167600  ETHUSD   14.26   16.05   14.24   14.26
# 2016-06-12      1465772400  ETHUSD   15.50   15.75   15.49   15.64
# ...                    ...     ...     ...     ...     ...     ...
# 2020-03-22   1584918000000  ETHUSD  151.00  153.17  148.03  151.00
# 2020-03-29   1585522800000  ETHUSD  141.09  144.14  140.04  141.09
# 2020-04-05   1586127600000  ETHUSD  146.46  150.32  144.85  146.46
# 2020-04-12   1586732400000  ETHUSD  174.87  176.74  173.60  174.87
# 2020-04-19   1586995200000  ETHUSD  161.72  162.15  160.07  161.72
#
#                   Volume  DayOfWeek
# Date
# 2016-05-15   1188.035235  Wednesday
# 2016-05-22   2627.413951  Wednesday
# 2016-05-29   7971.003922  Wednesday
# ...

# %%
dfs.resample('W').agg({'Close' : 'mean' , 'High' : 'max' , 'Low' : 'min' , 'Volume' : 'sum'})  #to give different aggregate functions
# Out:
#                  Close    High     Low         Volume
# Date
# 2016-05-15   10.205290   12.00    0.00   10988.942273
# 2016-05-22   13.066964   14.77   10.06   40673.495362
# 2016-05-29   12.471012   14.43   10.41   58051.809091
# 2016-06-05   13.594583   16.05   12.41   47351.544496
# 2016-06-12   14.297798   15.75   13.83   52002.171838
# ...                ...     ...     ...            ...
# 2020-03-22  124.636012  153.17  100.70  439980.283707
# 2020-03-29  133.285893  144.14  119.17  230941.584515
# 2020-04-05  137.627440  150.32  124.09  151022.864981
# 2020-04-12  163.693929  176.74  142.87  204715.937994
# 2020-04-19  156.778219  162.15  150.12   50776.889638
#
# [206 rows x 4 columns]

# %%
#Reading data from different type of files like csv , excel, sql etc

# %%
#we already learn how to read csv now lets see how to write back the updated file

# %%
df.head()
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
#
#                            OpenSourcer  \
# Respondent
# 1                                Never
# 2              Less than once per year
# 3                                Never
# 4                                Never
# 5           Once a month or more often
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
# 3           The quality of OSS and closed source software ...
# ...

# %%
filt = (df['Country'] == 'India')
india_df = df.loc[filt]
india_df.head()
# Out:
#                                         MainBranch Hobbyist  \
# Respondent
# 8                      I code primarily as a hobby      Yes
# 10                  I am a developer by profession      Yes
# 15          I am a student who is learning to code      Yes
# 50                  I am a developer by profession      Yes
# 65                  I am a developer by profession      Yes
#
#                            OpenSourcer  \
# Respondent
# 8              Less than once per year
# 10          Once a month or more often
# 15                               Never
# 50          Once a month or more often
# 65                               Never
#
#                                                    OpenSource  \
# Respondent
# 8           OSS is, on average, of HIGHER quality than pro...
# 10          OSS is, on average, of HIGHER quality than pro...
# 15          OSS is, on average, of HIGHER quality than pro...
# 50          OSS is, on average, of LOWER quality than prop...
# ...

# %%
india_df.to_csv('data/modified1.csv')

# %%
#read and write in TAB

# %%
india_df.to_csv('data/modified.tsv' , sep='\t')

# %%
#EXCEL  - install in terminal ---> pip install xlwt openpyxl xlrd

# %%
india_df.to_excel('data/modified.xlsx')

# %%
test = pd.read_excel('data/modified.xlsx',index_col = 'Respondent')

# %%
test.head()
# Out:
#                                         MainBranch Hobbyist  \
# Respondent
# 8                      I code primarily as a hobby      Yes
# 10                  I am a developer by profession      Yes
# 15          I am a student who is learning to code      Yes
# 50                  I am a developer by profession      Yes
# 65                  I am a developer by profession      Yes
#
#                            OpenSourcer  \
# Respondent
# 8              Less than once per year
# 10          Once a month or more often
# 15                               Never
# 50          Once a month or more often
# 65                               Never
#
#                                                    OpenSource  \
# Respondent
# 8           OSS is, on average, of HIGHER quality than pro...
# 10          OSS is, on average, of HIGHER quality than pro...
# 15          OSS is, on average, of HIGHER quality than pro...
# 50          OSS is, on average, of LOWER quality than prop...
# ...

# %%
#JSON

# %%
india_df.to_json('data/modified.json')

# %%
india_df.to_json('data/modified1.json' , orient='records' , lines = True)

# %%
test = pd.read_json('data/modified1.json' , orient='records' , lines = True)

# %%
test.head()
# Out:
#                                MainBranch Hobbyist  \
# 0             I code primarily as a hobby      Yes
# 1          I am a developer by profession      Yes
# 2  I am a student who is learning to code      Yes
# 3          I am a developer by profession      Yes
# 4          I am a developer by profession      Yes
#
#                   OpenSourcer  \
# 0     Less than once per year
# 1  Once a month or more often
# 2                       Never
# 3  Once a month or more often
# 4                       Never
#
#                                           OpenSource  \
# 0  OSS is, on average, of HIGHER quality than pro...
# 1  OSS is, on average, of HIGHER quality than pro...
# 2  OSS is, on average, of HIGHER quality than pro...
# 3  OSS is, on average, of LOWER quality than prop...
# 4                                               None
#
#                            Employment Country         Student  \
# 0  Not employed, but looking for work   India            None
# ...

# %%
#SQL - install package --> pip install SQLAlchemy , pip install psychopg2-binary
#ORM - object relational mapper to connect python objects to sql

# %%
from sqlalchemy import create_engine
import psycopg2

# %%
#need to check again - 21.00 - know about postgress
#engine = create_engine('postgressql://root:Kutti@2205@localhost:3306/lasya')  
#india_df.to_sql('Sample_table' , engine)
#india_df.to_sql('Sample_table' , engine , if_exists ='replace') --> it replaces if the table already exists
#to read
#sql_df = pd.read_sql('sample_table',engine,index_col='Respondent')
#to read query
##sql_df = pd.read_sql_query('SELECT* FROM sample_table',engine,index_col='Respondent')
#sql_df.head()

# %%
#URL

# %%
#posts_df = pd.read_json('')  
#we use read_json as the file is in json
#load any url inside
